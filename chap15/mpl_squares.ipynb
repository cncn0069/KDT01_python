# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\code\python\.venv\lib\site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\code\python\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\code\python\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\code\python\.venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\code\python\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\code\python\.venv\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\code\python\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\code\python\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\code\python\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\code\python\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\code\python\.venv\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\code\python\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\code\python\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %%
import matplotlib.pyplot as plt

squares = [1,4,9,16,25]
fig, ax= plt.subplots()
ax.plot(squares)
plt.show()

# %%
import numpy as np

def f(x):
    return x + 1

def f2(x):
    return x ** 2 + 2*x + 1

x = [1,2,3,4,5,6,7,8,9]
x = np.array(x)
plt.plot(x, f2(x))
plt.show()

# %%
import matplotlib.pyplot as plt

squares = np.array([1, 4, 9, 16, 25])

fig, ax = plt.subplots()
ax.plot(squares, linewidth=3)

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

ax.tick_params(labelsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

input_values = np.arange(5)
squares = np.array([1, 4, 9, 16, 25])

fig, ax = plt.subplots()
ax.plot(input_values,squares, linewidth=3)

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

ax.tick_params(labelsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt

input_values = [1,2,3,4,5]
squares = [1, 4, 9, 16, 25]

plt.style.use('_mpl-gallery')
fig, ax = plt.subplots()
ax.plot(input_values,squares, linewidth=3)

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

ax.tick_params(labelsize=14)

plt.show()
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()

x_values = np.arange(1,6)
y_values = x_values**2

ax.scatter(x_values, y_values, s=200,c='m')

plt.show()

# %%
x_values = np.arange(10)
y_values = x**2

ax.scatter(x_values, y_values, s=200,c='m')

plt.show()

# %%
x = np.arange(-10,10,0.1)
y = x**2

plt.scatter(x,y)

# %%
import matplotlib.pyplot as plt

x_values = range(1, 10001)
y_values = [x**3 for x in x_values]
plt.style.use('tableau-colorblind10')
fig, ax = plt.subplots()
ax.scatter(x_values,y_values,s=10,c=y_values, cmap=plt.cm.Blues)

ax.axis([0,1100, 0,1_000_000_000])
ax.ticklabel_format(style='plain')
plt.show()

# %%
import random

x = [random.randint(1,9) for _ in range(100)]
y = [random.randint(1,9) for _ in range(100)]

plt.plot(x,y)
plt.show()

# %%
from random import choice

class RandomWalk:
    """랜덤 워크"""

    def __init__(self,num_points = 50000):
        self.num_points = num_points

        self.x_values = [0]
        self.y_values = [0]

    def file_walk(self):
        while len(self.x_values) < self.num_points:
            x_dirction = choice([1,-1])
            x_distance = choice([_ for _ in range(5)])
            x_step = x_dirction * x_distance

            y_dirction = choice([1,-1])
            y_distance = choice([_ for _ in range(5)])
            y_step = y_dirction * y_distance

            if x_step == 0 and y_step == 0:
                continue

            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step

            self.x_values.append(x)
            self.y_values.append(y)

# %%
import matplotlib.pyplot as plt

rw = RandomWalk()
rw.file_walk()

plt.style.use('classic')
fig, ax = plt.subplots()
ax.scatter(rw.x_values, rw.y_values, s=15)
ax.set_aspect('equal')
plt.show()
